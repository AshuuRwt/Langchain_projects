# %%
# !pip install arxiv
# Out:
# Requirement already satisfied: arxiv in c:\users\rawat\onedrive\documents\langchain_chatbot1\venv\lib\site-packages (2.3.1)
# Requirement already satisfied: feedparser~=6.0.10 in c:\users\rawat\onedrive\documents\langchain_chatbot1\venv\lib\site-packages (from arxiv) (6.0.12)
# Requirement already satisfied: requests~=2.32.0 in c:\users\rawat\onedrive\documents\langchain_chatbot1\venv\lib\site-packages (from arxiv) (2.32.5)
# Requirement already satisfied: sgmllib3k in c:\users\rawat\onedrive\documents\langchain_chatbot1\venv\lib\site-packages (from feedparser~=6.0.10->arxiv) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rawat\onedrive\documents\langchain_chatbot1\venv\lib\site-packages (from requests~=2.32.0->arxiv) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rawat\onedrive\documents\langchain_chatbot1\venv\lib\site-packages (from requests~=2.32.0->arxiv) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rawat\onedrive\documents\langchain_chatbot1\venv\lib\site-packages (from requests~=2.32.0->arxiv) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rawat\onedrive\documents\langchain_chatbot1\venv\lib\site-packages (from requests~=2.32.0->arxiv) (2025.11.12)

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# %%
api_wrapper=WikipediaAPIWrapper(top_k_results=1,doc_content_chars_max=200)
wiki=WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings

loader = WebBaseLoader("https://docs.smith.langchain.com/")
docs = loader.load()

documents = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
).split_documents(docs)

embeddings = OllamaEmbeddings(model="nomic-embed-text")
vectordb = FAISS.from_documents(documents, embeddings)

retriever = vectordb.as_retriever()

# %%
from langchain.tools.retriever import create_retriever_tool
retriever_tool=create_retriever_tool(retriever,"langsmith_search",
                      "Search for information about LangSmith. For any questions about LangSmith, you must use this tool!")

# %%
from langchain_community.utilities import ArxivAPIWrapper
from langchain_community.tools import ArxivQueryRun

arxiv_wrapper = ArxivAPIWrapper(top_k_results=1, doc_content_chars_max=200)
arxiv = ArxivQueryRun(api_wrapper=arxiv_wrapper)

# %%
tools = [wiki, arxiv, retriever_tool]

# %%
from langchain_community.chat_models import ChatOllama

llm = ChatOllama(
    model="llama3",
    temperature=0
)

# %%
from langchain import hub

prompt = hub.pull("hwchase17/openai-functions-agent")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\rawat\OneDrive\Documents\Langchain_chatbot1\venv\Lib\site-packages\langchain\hub.py:18, in _get_client(api_url, api_key)
#      17 try:
# ---> 18     from langchainhub import Client
#      19 except ImportError as e:
#
# ModuleNotFoundError: No module named 'langchainhub'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 3
#       1 from langchain import hub
# ----> 3 prompt = hub.pull("hwchase17/openai-functions-agent")
#
# File c:\Users\rawat\OneDrive\Documents\Langchain_chatbot1\venv\Lib\site-packages\langchain\hub.py:82, in pull(owner_repo_commit, api_url, api_key)
#      67 def pull(
#      68     owner_repo_commit: str,
#      69     *,
#      70     api_url: Optional[str] = None,
#      71     api_key: Optional[str] = None,
#      72 ) -> Any:
#      73     """
#      74     Pulls an object from the hub and returns it as a LangChain object.
#      75
#    (...)     80     :param api_key: The API key to use to authenticate with the LangChain Hub API.
#      81     """
# ---> 82     client = _get_client(api_url=api_url, api_key=api_key)
#      84     if hasattr(client, "pull_repo"):
#      85         # >= 0.1.15
#      86         res_dict = client.pull_repo(owner_repo_commit)
#
# File c:\Users\rawat\OneDrive\Documents\Langchain_chatbot1\venv\Lib\site-packages\langchain\hub.py:20, in _get_client(api_url, api_key)
#      18     from langchainhub import Client
#      19 except ImportError as e:
# ---> 20     raise ImportError(
#      21         "Could not import langchainhub, please install with `pip install "
#      22         "langchainhub`."
#      23     ) from e
#      25 # Client logic will also attempt to load URL/key from environment variables
#      26 return Client(api_url, api_key=api_key)
#
# ImportError: Could not import langchainhub, please install with `pip install langchainhub`.
